# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswar-123/DA2/blob/main/Dia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
member_names=["Aman","Riya","Kiran","Sneha","Rahul"]
ages=[22,25,24,23,26]
workout_hours=[2,1.5,2.5,1,3]
calories_burned=[500,350,600,400,500] # Corrected to match the length of member_names
print("----Fitness Center Dataset-----")
for i in range(len(member_names)):
  print(member_names[i],ages[i],workout_hours[i],calories_burned[i])
average_workout=sum(workout_hours)/len(workout_hours)
print("\n average_WO",average_workout)
average_calories=sum(calories_burned)/len(calories_burned) # Corrected variable name
print("\n average_calories",average_calories)
high_calories=max(calories_burned) # Corrected variable name
print("\n high_calories",high_calories)
low_calories=min(calories_burned) # Corrected variable name
print("\n low_calories",low_calories)
low_workout=min(workout_hours)
print("\n low_workout",low_workout)
high_workout=max(workout_hours)
print("\n high_workout",high_workout)
median_calories=statistics.median(calories_burned) # Corrected variable name
print("\n median_calories",median_calories)
median_workout=statistics.median(workout_hours)
print("\n median_workout",median_workout)
median_age=statistics.median(ages)
print("\n median_age",median_age)
std_calories=statistics.stdev(calories_burned) # Corrected variable name
print("\n std_calories",std_calories)
std_workout=statistics.stdev(workout_hours)
print("\n std_workout",std_workout)
index=calories_burned.index(high_calories)
print("\n member with high activeness",member_names[index])
index=calories_burned.index(low_calories)
print("\n member with low activeness",member_names[index])
# Out:
# ----Fitness Center Dataset-----
# Aman 22 2 500
# Riya 25 1.5 350
# Kiran 24 2.5 600
# Sneha 23 1 400
# Rahul 26 3 500
#
#  average_WO 2.0
#
#  average_calories 470.0
#
#  high_calories 600
#
#  low_calories 350
#
#  low_workout 1
#
#  high_workout 3
#
#  median_calories 500
#
#  median_workout 2
#
#  median_age 24
#
#  std_calories 97.46794344808964
#
#  std_workout 0.7905694150420949
#
#  member with high calories Kiran
#
#  member with low calories Riya

# %%
import matplotlib.pyplot as plt
plt.bar(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Calories Burned by Members")
plt.show()

# %%
import matplotlib.pyplot as plt
min_workout_hours = 2.0 # Define minimum workout hours to be considered active
min_calories_burned = 400 # Define minimum calories burned to be considered active

active_members = []

for i in range(len(member_names)):
    if workout_hours[i] >= min_workout_hours and calories_burned[i] >= min_calories_burned:
        active_members.append(member_names[i])

print(f"Members considered active (workout >= {min_workout_hours} hrs AND calories burned >= {min_calories_burned}): {active_members}")
print(f"Number of active members: {len(active_members)}")
total_members = len(member_names)
proportion_active = len(active_members) / total_members

print(f"Total members: {total_members}")
print(f"Proportion of active members: {proportion_active:.2f} ({len(active_members)} out of {total_members})")
non_active_members = []
for i in range(len(member_names)):
    if member_names[i] not in active_members:
        non_active_members.append(member_names[i])

print(f"Non-active members: {non_active_members}")
print(f"Number of non-active members: {len(non_active_members)}")
plt.figure(figsize=(10, 6))

# Data for plotting
labels = ['Active Members', 'Non-Active Members']
mean_calories_active = np.mean(active_calories_burned) if active_calories_burned else 0
mean_calories_non_active = np.mean(non_active_calories_burned) if non_active_calories_burned else 0

x = np.arange(len(labels))
width = 0.35

plt.bar(x[0], mean_calories_active, width, label='Active Members', color='lightgreen')
plt.bar(x[1], mean_calories_non_active, width, label='Non-Active Members', color='salmon')

plt.ylabel('Average Calories Burned')
plt.title('Average Calories Burned for Active vs. Non-Active Members')
plt.xticks(x, labels)
plt.legend()
plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec5c242d-307f-4123-bde6-a3999bb02cd9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec5c242d-307f-4123-bde6-a3999bb02cd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_excel("Customers.xlsx")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
minage=df["Age"].min()
maxage=df["Age"].max()
mean_age=df["Age"].mean()
median=df["Age"].median()
std=df["Age"].std()
print(minage)
print(maxage)
print(mean_age)
print(median)
print(std)
gender_count=df['Genre'].value_counts()
print(gender_count)
# Out:
# 18
# 70
# 38.85
# 36.0
# 13.969007331558878
# Genre
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
min_income=df["Annual_Income_(k$)"].min()
max_income=df["Annual_Income_(k$)"].max()
print(min_income)
print(max_income)
mean_income=df["Annual_Income_(k$)"].mean()
median_income=df["Annual_Income_(k$)"].median()
std_income=df["Annual_Income_(k$)"].std()
print(mean_income)
print(median_income)
print(std_income)
# Out:
# 15
# 137
# 60.56
# 61.5
# 26.264721165271247

# %%
df["Age_group"]=pd.cut(df["Age"],bins=[17,30,40,50,60,71],labels=["18-29","30-39","40-49","50-59","60-70"])
df.head()
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  gender_code  \
# 33           34    Male   18                  33              92            1
# 114         115  Female   18                  65              48            0
# 91           92    Male   18                  59              41            1
# 65           66    Male   18                  48              59            1
# 68           69    Male   19                  48              59            1
#
#     Age_group
# 33      18-29
# 114     18-29
# 91      18-29
# 65      18-29
# 68      18-29

# %%
df["gender_code"]=df["Genre"].map({"Female":0,"Male":1})
df.head()
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  gender_code  \
# 33           34    Male   18                  33              92            1
# 114         115  Female   18                  65              48            0
# 91           92    Male   18                  59              41            1
# 65           66    Male   18                  48              59            1
# 68           69    Male   19                  48              59            1
#
#     Age_group
# 33      18-29
# 114     18-29
# 91      18-29
# 65      18-29
# 68      18-29

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.bar(gender_count.index,gender_count.values)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution")
plt.show()


plt.figure(figsize=(8,5))
plt.pie(gender_count.values,labels=gender_count.index,autopct="%1.1f%%")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.figure(figsize=(10,6))

plt.bar(
    df["Annual_Income_(k$)"],
    df["Spending_Score"]
)

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Annual Income vs Spending Score")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by Age Group
group_data = df.groupby("Age_group")[["Annual_Income_(k$)", "Spending_Score"]].mean()

# Bar Chart
group_data.plot(
    kind='bar',
    figsize=(10,6)
)

plt.xlabel("Age Group")
plt.ylabel("Average Value")
plt.title("Age Group vs Income and Spending")

plt.show()
# Out:
# /tmp/ipykernel_11631/5868834.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_data = df.groupby("Age_group")[["Annual_Income_(k$)", "Spending_Score"]].mean()

# %%
income_analysis = df.groupby("Age_group")["Annual_Income_(k$)"].mean()

print(income_analysis.sort_values(ascending=False))
plt.figure(figsize=(8,5))

plt.bar(
    income_analysis.index,
    income_analysis.values
)

plt.xlabel("Age Group")
plt.ylabel("Average Annual Income")
plt.title("Age Group vs Annual Income")

plt.show()
# Out:
# Age_group
# 30-39    68.633333
# 40-49    63.605263
# 50-59    56.695652
# 18-29    55.209677
# 60-70    50.000000
# Name: Annual_Income_(k$), dtype: float64
# /tmp/ipykernel_11631/1455178342.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   income_analysis = df.groupby("Age_group")["Annual_Income_(k$)"].mean()

# %%
spending_analysis = df.groupby("Age_group")["Spending_Score"].mean()

print(spending_analysis.sort_values(ascending=False))
plt.figure(figsize=(8,5))

plt.bar(
    spending_analysis.index,
    spending_analysis.values
)

plt.xlabel("Age Group")
plt.ylabel("Average spending score")
plt.title("Age Group vs spending score")

plt.show()
# Out:
# Age_group
# 18-29    61.032258
# 30-39    57.500000
# 60-70    44.176471
# 40-49    34.394737
# 50-59    32.521739
# Name: Spending_Score, dtype: float64
# /tmp/ipykernel_11631/1719061208.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_analysis = df.groupby("Age_group")["Spending_Score"].mean()

# %%
#low spend age groups count of males and females
low_spending=["40-49","50-59"]
lsd=df[df["Age_group"].isin(low_spending)]
gender_count=lsd['Genre'].value_counts()
print(gender_count)
# Out:
# Genre
# Female    37
# Male      24
# Name: count, dtype: int64

# %%
cs=df.to_csv("Customers.csv")
