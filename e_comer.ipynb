# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneswar-123/DA2/blob/main/e_comer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-66e29ef8-ca56-42c4-bd19-e072bd23a364" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66e29ef8-ca56-42c4-bd19-e072bd23a364">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("e_comerece.csv")
df.head()
# Out:
#    Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0    15.0             29.0                         4  Laptop & Accessory
# 1     7.0             25.0                         4              Mobile
# 2    27.0             13.0                         3  Laptop & Accessory
# 3    20.0             25.0                         4             Fashion
# 4    30.0             15.0                         4              Others
#
#    SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                  3        Single                2         0
# 1                  1       Married                2         0
# 2                  1       Married                5         0
# 3                  3      Divorced                7         0
# 4                  4        Single                8         0
#
#    DaySinceLastOrder  CashbackAmount  Churn
# 0                7.0          143.32      0
# 1                7.0          129.29      0
# ...

# %%
df.head()
# Out:
#    Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0    15.0             29.0                         4  Laptop & Accessory
# 1     7.0             25.0                         4              Mobile
# 2    27.0             13.0                         3  Laptop & Accessory
# 3    20.0             25.0                         4             Fashion
# 4    30.0             15.0                         4              Others
#
#    SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                  3        Single                2         0
# 1                  1       Married                2         0
# 2                  1       Married                5         0
# 3                  3      Divorced                7         0
# 4                  4        Single                8         0
#
#    DaySinceLastOrder  CashbackAmount  Churn
# 0                7.0          143.32      0
# 1                7.0          129.29      0
# ...

# %%
df['DaySinceLastOrder'] = df['DaySinceLastOrder'].fillna(0)

# %%
display(df.head())
# Out:
#    Tenure  WarehouseToHome  NumberOfDeviceRegistered    PreferedOrderCat  \
# 0    15.0             29.0                         4  Laptop & Accessory
# 1     7.0             25.0                         4              Mobile
# 2    27.0             13.0                         3  Laptop & Accessory
# 3    20.0             25.0                         4             Fashion
# 4    30.0             15.0                         4              Others
#
#    SatisfactionScore MaritalStatus  NumberOfAddress  Complain  \
# 0                  3        Single                2         0
# 1                  1       Married                2         0
# 2                  1       Married                5         0
# 3                  3      Divorced                7         0
# 4                  4        Single                8         0
#
#    DaySinceLastOrder  CashbackAmount  Churn
# 0                7.0          143.32      0
# 1                7.0          129.29      0
# ...

# %%
df['Tenure']=df['Tenure'].fillna(df['Tenure'].mean())

# %%
df['WarehouseToHome']=df['WarehouseToHome'].fillna(df['WarehouseToHome'].mean())

# %%
mean_day=df['DaySinceLastOrder'].mean()
print(mean)
mean_ware=df['WarehouseToHome'].mean()
print(mean_ware)
mean_sat=df['SatisfactionScore'].mean()
print(mean_sat)
mean_ten=df['Tenure'].mean()
print(mean_ten)
mean_cash=df['CashbackAmount'].mean()
print(mean_cash)
# Out:
# 4.286729256533874
# 15.650583244962885
# 3.0883024613042376
# 10.08139845209501
# 176.7074194366912

# %%
result = df[df['WarehouseToHouse'] > mean_ware]['Churn'].value_counts()
print(result)
# Out:
# Churn
# 0    1187
# 1     293
# Name: count, dtype: int64

# %%
result = df[df['DaySinceLastOrder'] > mean_day]['Churn'].value_counts()
print(result)
# Out:
# Churn
# 0    1288
# 1     167
# Name: count, dtype: int64

# %%
result = df[df['SatisfactionScore'] > mean_sat]['Churn'].value_counts()
print(result)
# Out:
# Churn
# 0    1235
# 1     319
# Name: count, dtype: int64

# %%
result = df[df['Tenure'] > mean_ten]['Churn'].value_counts()
print(result)
# Out:
# Churn
# 0    1491
# 1      73
# Name: count, dtype: int64

# %%
result = df[df['CashbackAmount'] > mean_cash]['Churn'].value_counts()
print(result)
# Out:
# Churn
# 0    1304
# 1     157
# Name: count, dtype: int64

# %%
result2=df[(df['WarehouseToHome'] > mean_ware)&(df['DaySinceLastOrder'] > mean_day)&(df['SatisfactionScore'] > mean_sat)&(df['Tenure'] > mean_ten)&(df['CashbackAmount'] > mean_cash)]['Churn'].value_counts()
print(result2)
# Out:
# Churn
# 0    65
# 1     2
# Name: count, dtype: int64
